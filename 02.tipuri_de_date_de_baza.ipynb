# %% [markdown]
# # 1. Boolean

# %%
x = True
print(x, type(x))
# Out:
# True <class 'bool'>

# %% [markdown]
# # 2. Integer

# %%
x = 1
print(x, type(x))
# Out:
# 1 <class 'int'>

# %% [markdown]
# # 3. Floating number

# %%
x = 1.42
print(x, type(x))
# Out:
# 1.42 <class 'float'>

# %% [markdown]
# # 4. String

# %%
x = "Hello"
print(x, type(x))
# Out:
# Hello <class 'str'>

# %%
x = 'Hello'
print(x, type(x))
# Out:
# Hello <class 'str'>

# %% [markdown]
# ## Operatii :
# # 1. Matematice

# %%
1 + 2
# Out:
# 3

# %%
1 + True    # True este evaluat la 1
# Out:
# 2

# %%
1 + 2.0 # Int se converteste automat la Float
# Out:
# 3.0

# %%
1 + "text"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 1 + "text"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
3 * "text"
# Out:
# 'texttexttext'

# %% [markdown]
# # Concatenarea stringurilor

# %%
"text" + "text" + "text"
# Out:
# 'texttexttext'

# %%
"ala" + "bala" + "portacala"
# Out:
# 'alabalaportacala'

# %% [markdown]
# # 2. Logice

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %%
10 or 20
# Out:
# 10

# %%
bool(10) or bool(20)
# Out:
# True

# %%
10 and 20
# Out:
# 20

# %%
bool(10) and bool(20)
# Out:
# True

# %% [markdown]
# ## Conversii
# # 1. La bool

# %%
bool(10), bool(-320), bool(0)
# Out:
# (True, True, False)

# %%
bool(10.321), bool(-320.5431), bool(0.0)
# Out:
# (True, True, False)

# %%
bool("hello"), bool(" "), bool("0"), bool("")
# Out:
# (True, True, True, False)

# %% [markdown]
# # 2. La int

# %%
int(True), int(False)
# Out:
# (1, 0)

# %%
int(1.232), int(23.99)
# Out:
# (1, 23)

# %%
int("41543")
# Out:
# 41543

# %%
int("41543FdFA")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 int("41543FdFA")
#
# ValueError: invalid literal for int() with base 10: '41543FdFA'

# %% [markdown]
# # 3. Float

# %%
float(True), float(False)
# Out:
# (1.0, 0.0)

# %%
float(1312), float(23)
# Out:
# (1312.0, 23.0)

# %%
float("41543"), float("3215.33")
# Out:
# (41543.0, 3215.33)

# %%
float("romania")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 float("romania")
#
# ValueError: could not convert string to float: 'romania'
