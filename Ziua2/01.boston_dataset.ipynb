# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # pip install pandas

# %%
import pandas as pd

# %% [markdown]
# # sursa dataset: https://www.kaggle.com/code/prasadperera/the-boston-housing-dataset

# %%
column_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
df = pd.read_csv("datasets/Boston_data.csv", names = column_names, header=None, delimiter=r"\s+")
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
df = pd.read_csv("datasets/Boston_cu_headere.csv", index_col=0)
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 1    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 2    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 3    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 4    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 5    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 1       15.3  396.90   4.98  24.0
# 2       17.8  396.90   9.14  21.6
# ...

# %%
df.dtypes
# Out:
# crim       float64
# zn         float64
# indus      float64
# chas         int64
# nox        float64
# rm         float64
# age        float64
# dis        float64
# rad          int64
# tax          int64
# ptratio    float64
# black      float64
# lstat      float64
# medv       float64
# dtype: object

# %%
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       black  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.keys()
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
medv = df["medv"]
type(medv)
# Out:
# pandas.core.series.Series

# %%
medv = df[ [ "medv"] ]
type(medv)
# Out:
# pandas.core.frame.DataFrame

# %%
# pentru a lua o coloana doar cu 1 singur set de paranteze drepte -> Serie
df[  "medv" ]
# Out:
# 1      24.0
# 2      21.6
# 3      34.7
# 4      33.4
# 5      36.2
#        ...
# 502    22.4
# 503    20.6
# 504    23.9
# 505    22.0
# 506    11.9
# Name: medv, Length: 506, dtype: float64

# %%
# pentru a lua o coloana cu 2 seturi de paranteze drepte -> DataFrame
y = df[ [ "medv"] ]
y
# Out:
#      medv
# 1    24.0
# 2    21.6
# 3    34.7
# 4    33.4
# 5    36.2
# ..    ...
# 502  22.4
# 503  20.6
# 504  23.9
# 505  22.0
# 506  11.9
#
# [506 rows x 1 columns]

# %%
df.keys()
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
x = df[['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
       'ptratio', 'black', 'lstat']]
x
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 1    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 2    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 3    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 4    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 5    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat
# 1       15.3  396.90   4.98
# 2       17.8  396.90   9.14
# 3       17.8  392.83   4.03
# ...

# %%
x = df.drop("medv", axis=1) # axis=0 orizontala si axis=1 este pe verticala
x
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 1    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 2    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 3    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 4    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 5    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat
# 1       15.3  396.90   4.98
# 2       17.8  396.90   9.14
# 3       17.8  392.83   4.03
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((379, 13), (127, 13), (379, 1), (127, 1))

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)#, random_state=142)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((404, 13), (102, 13), (404, 1), (102, 1))

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_prezis = model.predict(x_train)
y_prezis
# Out:
# array([[30.63557783],
#        [23.61465443],
#        [17.5206977 ],
#        [22.61755634],
#        [32.91150104],
#        [23.26104039],
#        [34.15156835],
#        [ 2.31380495],
#        [27.46575388],
#        [21.23897432],
#        [15.42027511],
#        [13.49061833],
#        [13.18802779],
#        [10.81059139],
#        [32.60205226],
#        [34.06926004],
#        [24.73566481],
#        [37.72438144],
#        [15.70137133],
#        [34.78861501],
#        [19.26553398],
#        [19.93551643],
#        [27.00839677],
#        [30.62741464],
#        [13.75958704],
#        [30.86264521],
#        [23.17774722],
#        [21.52344836],
#        [24.95187786],
#        [28.77414057],
#        [30.55451781],
#        [20.26926385],
#        [25.42343769],
#        [18.49489466],
#        [12.04063218],
#        [19.22139457],
#        [40.37981068],
#        [36.15801147],
#        [17.37133754],
#        [19.94279145],
#        [22.32011469],
# ...

# %%
real_vs_prezis_df = pd.DataFrame({"y_real":y_train["medv"], "y_prezis":y_prezis.flatten()})
real_vs_prezis_df
# Out:
#      y_real   y_prezis
# 267    30.7  30.635578
# 209    24.4  23.614654
# 69     17.4  17.520698
# 211    21.7  22.617556
# 161    27.0  32.911501
# ..      ...        ...
# 342    32.7  29.970968
# 192    30.5  30.093956
# 406     5.0  10.394763
# 57     24.7  24.566029
# 450    13.0  17.786691
#
# [404 rows x 2 columns]

# %%
real_vs_prezis_df["score"] = real_vs_prezis_df["y_real"] - real_vs_prezis_df["y_prezis"]
real_vs_prezis_df
# Out:
#      y_real   y_prezis     score
# 267    30.7  30.635578  0.064422
# 209    24.4  23.614654  0.785346
# 69     17.4  17.520698 -0.120698
# 211    21.7  22.617556 -0.917556
# 161    27.0  32.911501 -5.911501
# ..      ...        ...       ...
# 342    32.7  29.970968  2.729032
# 192    30.5  30.093956  0.406044
# 406     5.0  10.394763 -5.394763
# 57     24.7  24.566029  0.133971
# 450    13.0  17.786691 -4.786691
#
# [404 rows x 3 columns]

# %%
real_vs_prezis_df["score"] = (real_vs_prezis_df["y_real"] - real_vs_prezis_df["y_prezis"]) ** 2
real_vs_prezis_df
# Out:
#      y_real   y_prezis      score
# 267    30.7  30.635578   0.004150
# 209    24.4  23.614654   0.616768
# 69     17.4  17.520698   0.014568
# 211    21.7  22.617556   0.841910
# 161    27.0  32.911501  34.945845
# ..      ...        ...        ...
# 342    32.7  29.970968   7.447615
# 192    30.5  30.093956   0.164872
# 406     5.0  10.394763  29.103470
# 57     24.7  24.566029   0.017948
# 450    13.0  17.786691  22.912412
#
# [404 rows x 3 columns]

# %%
real_vs_prezis_df["score"] = np.sqrt((real_vs_prezis_df["y_real"] - real_vs_prezis_df["y_prezis"]) ** 2)
real_vs_prezis_df
# Out:
#      y_real   y_prezis     score
# 267    30.7  30.635578  0.064422
# 209    24.4  23.614654  0.785346
# 69     17.4  17.520698  0.120698
# 211    21.7  22.617556  0.917556
# 161    27.0  32.911501  5.911501
# ..      ...        ...       ...
# 342    32.7  29.970968  2.729032
# 192    30.5  30.093956  0.406044
# 406     5.0  10.394763  5.394763
# 57     24.7  24.566029  0.133971
# 450    13.0  17.786691  4.786691
#
# [404 rows x 3 columns]

# %%
real_vs_prezis_df["score"].sum()
# Out:
# np.float64(1371.3372928610129)

# %%
real_vs_prezis_df["score"].sum() / real_vs_prezis_df["score"].count()
# Out:
# np.float64(3.3943992397549825)

# %%
real_vs_prezis_df["score"].mean()
# Out:
# np.float64(3.3943992397549825)

# %%
real_vs_prezis_df["score"].mean() / 2
# Out:
# np.float64(1.6971996198774912)

# %%
from sklearn.metrics import r2_score

# %%
y_prezis = model.predict(x_train)
r2_score(y_train, y_prezis)
# Out:
# 0.7184285410428757

# %%
model.score(x_train, y_train)
# Out:
# 0.7184285410428757

# %%
x.iloc[100]
# Out:
# crim         0.14866
# zn           0.00000
# indus        8.56000
# chas         0.00000
# nox          0.52000
# rm           6.72700
# age         79.90000
# dis          2.77780
# rad          5.00000
# tax        384.00000
# ptratio     20.90000
# black      394.76000
# lstat        9.42000
# Name: 101, dtype: float64

# %%
model.predict([x.iloc[100]])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[24.4933754]])

# %% [markdown]
# # Antrenarea unui alt model de regresie liniara

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn_model = KNeighborsRegressor(n_neighbors=3)
knn_model
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
knn_model.fit(x_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
model
# Out:
# LinearRegression()

# %%
knn_model.score(x_train, y_train)
# Out:
# 0.7735887436805016

# %%
model.score(x_train, y_train)
# Out:
# 0.7184285410428757

# %%
knn_scores = {}


for k in range(2, 11):
    inner_knn_model = KNeighborsRegressor(n_neighbors=k)
    inner_knn_model.fit(x_train, y_train)
    score_result =  inner_knn_model.score(x_train, y_train)
    knn_scores[k] = score_result

# %%
knn_scores
# Out:
# {2: 0.8181125594753362,
#  3: 0.7735887436805016,
#  4: 0.7285566096927669,
#  5: 0.676839924703627,
#  6: 0.6608058020686294,
#  7: 0.6258894182998389,
#  8: 0.5918199370862103,
#  9: 0.5800937585806873,
#  10: 0.5521585507365508}

# %%
score_values = np.array(list(knn_scores.values()))
score_values.max(), score_values.argmax()
# Out:
# (np.float64(0.8181125594753362), np.int64(0))

# %%
from sklearn.model_selection import GridSearchCV

# %%
estimator_model = KNeighborsRegressor()
estimator_model
# Out:
# KNeighborsRegressor()

# %%
parameter_grid = {'n_neighbors' : range(2, 11)}

# %%
grid_model = GridSearchCV(estimator_model, parameter_grid)
grid_model
# Out:
# GridSearchCV(estimator=KNeighborsRegressor(),
#              param_grid={'n_neighbors': range(2, 11)})

# %%
grid_model.fit(x_train, y_train)
grid_model
# Out:
# GridSearchCV(estimator=KNeighborsRegressor(),
#              param_grid={'n_neighbors': range(2, 11)})

# %%
grid_model.score(x_test, y_test)
# Out:
# 0.556440288333327

# %%
grid_model.best_estimator_
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
grid_model.best_estimator_.n_neighbors
# Out:
# 3

# %%
grid_model.best_estimator_.score(x_test, y_test)
# Out:
# 0.556440288333327
