# %% [markdown]
# # pip install matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.scatter(2, 3)

# %%
plt.scatter([2, 5], [3, 7])

# %%
x = np.array([2, 5, 5])
y = np.array([3, 5, 9])
plt.scatter(x, y)

# %%
x = np.array([2, 5, 5])
y = np.array([3, 5, 9])
plt.plot(x, y)

# %%
x = np.array([2, 5, 5])
y = np.array([3, 5, 9])
plt.plot(x, y)
plt.scatter(x, y)

# %%
x = np.array([2, 5, 5])
y = np.array([3, 5, 9])
plt.bar(x, y)
# Out:
# <BarContainer object of 3 artists>

# %%
x = np.array([2, 5, 5])
y = np.array([3, 5, 9])
plt.barh(x, y)
# Out:
# <BarContainer object of 3 artists>

# %%
x = np.array([2, 5, 5])
y = np.array([3, 5, 9])
plt.pie(x)
# Out:
# ([<matplotlib.patches.Wedge at 0x114e2b4d0>,
# ...
#  [Text(0.9526279361491276, 0.5500000138802306, ''),
#   Text(-0.7778174639428924, 0.7778174546675123, ''),
#   Text(0.2847009066928381, -1.062518420418336, '')])
