# %% [markdown]
# # pip install scikit-learn

# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np

# %%
type(make_regression())
# Out:
# tuple

# %%
x, y = make_regression()
x.shape, y.shape
# Out:
# ((100, 100), (100,))

# %%
x, y = make_regression(n_samples=10, n_features=1)
x.shape, y.shape
# Out:
# ((10, 1), (10,))

# %%
plt.scatter(x, y)
plt.plot(x, y)
plt.xlabel("Coordonata X")
plt.ylabel("Coordonata Y")
# Out:
# Text(0, 0.5, 'Coordonata Y')

# %%
x, y = make_regression(n_samples=10, n_features=1)
plt.scatter(x, y)
plt.plot(x, y)
plt.xlabel("Coordonata X")
plt.ylabel("Coordonata Y")
# Out:
# Text(0, 0.5, 'Coordonata Y')

# %%
NOISE = 1

x, y = make_regression(n_samples=10, n_features=1, noise= NOISE )
plt.scatter(x, y)

plt.xlabel("Coordonata X")
plt.ylabel("Coordonata Y")
# Out:
# Text(0, 0.5, 'Coordonata Y')

# %%
NOISE = 5

x, y = make_regression(n_samples=10, n_features=1, noise= NOISE )
plt.scatter(x, y)

plt.xlabel("Coordonata X")
plt.ylabel("Coordonata Y")
# Out:
# Text(0, 0.5, 'Coordonata Y')

# %%
NOISE = 5

x, y = make_regression(n_samples=100, n_features=1, noise= NOISE )
plt.scatter(x, y)

plt.xlabel("Coordonata X")
plt.ylabel("Coordonata Y")
# Out:
# Text(0, 0.5, 'Coordonata Y')

# %%
NOISE = 50
SAMPLES = 100

x, y = make_regression(n_samples=SAMPLES, n_features=1, noise= NOISE )
plt.scatter(x, y)

plt.xlabel("Coordonata X")
plt.ylabel("Coordonata Y")
# Out:
# Text(0, 0.5, 'Coordonata Y')

# %%
NOISE = 50
SAMPLES = 1000

x, y = make_regression(n_samples=SAMPLES, n_features=1, noise= NOISE )
plt.scatter(x, y)

plt.xlabel("Coordonata X")
plt.ylabel("Coordonata Y")
# Out:
# Text(0, 0.5, 'Coordonata Y')

# %%
NOISE = 1
SAMPLES = 10

x, y = make_regression(n_samples=SAMPLES, n_features=1, noise= NOISE )
plt.scatter(x, y)

plt.xlabel("Coordonata X")
plt.ylabel("Coordonata Y")
# Out:
# Text(0, 0.5, 'Coordonata Y')

# %%
x
# Out:
# array([[-1.14008169],
#        [-0.44702885],
#        [-0.66190952],
#        [ 0.39761962],
#        [-0.4305579 ],
#        [ 0.75095396],
#        [-1.01989507],
#        [-0.72002375],
#        [ 0.05638347],
#        [-0.57418905]])

# %%
y
# Out:
# array([-8.76371088, -2.19382338, -4.34169481,  2.34163251, -3.31672029,
#         5.21360778, -6.4661251 , -3.83048984,  0.33773026, -2.99992111])

# %%
y.shape
# Out:
# (10,)

# %%
x.shape
# Out:
# (10, 1)
