# %%
True and False
# Out:
# False

# %%
def AND_clasic(x1, x2):
    print(x1, "and", x2, "=", x1 and x2)

# %%
AND_clasic(True, True)
AND_clasic(False, True)
AND_clasic(True, False)
AND_clasic(False, False)
# Out:
# True and True = True
# False and True = False
# True and False = False
# False and False = False

# %%
AND_clasic(1, 1)
AND_clasic(0, 1)
AND_clasic(1, 0)
AND_clasic(0, 0)
# Out:
# 1 and 1 = 1
# 0 and 1 = 0
# 1 and 0 = 0
# 0 and 0 = 0

# %%
def AND_neuron(x1, x2):
    w1  = 0
    w2  = 0
    b   = 0
    rezultat = w1 * x1 + w2 * x2 + b
    print(x1, "and", x2, "=", rezultat)

# %%
AND_neuron(1, 1)
AND_neuron(0, 1)
AND_neuron(1, 0)
AND_neuron(0, 0)
# Out:
# 1 and 1 = 0
# 0 and 1 = 0
# 1 and 0 = 0
# 0 and 0 = 0

# %% [markdown]
# # Ideea de neuron -> ajustarea ponderilor w1, w2, b

# %%
def functie_de_activare(x):
    return x

def AND_neuron(x1, x2):
    w1  = 0
    w2  = 0
    b   = 0
    rezultat = functie_de_activare(w1 * x1 + w2 * x2 + b)
    print(x1, "and", x2, "=", rezultat)

AND_neuron(1, 1)
AND_neuron(0, 1)
AND_neuron(1, 0)
AND_neuron(0, 0)
# Out:
# 1 and 1 = 0
# 0 and 1 = 0
# 1 and 0 = 0
# 0 and 0 = 0

# %%
def functie_de_activare(x):
    return x

def AND_neuron(x1, x2):
    w1  = 1 # Din 0 in 1
    w2  = 0
    b   = 0
    rezultat = functie_de_activare(w1 * x1 + w2 * x2 + b)
    print(x1, "and", x2, "=", rezultat)

AND_neuron(1, 1)
AND_neuron(0, 1)
AND_neuron(1, 0)
AND_neuron(0, 0)
# Out:
# 1 and 1 = 1
# 0 and 1 = 0
# 1 and 0 = 1
# 0 and 0 = 0

# %%
def functie_de_activare(x):
    return x

def AND_neuron(x1, x2):
    w1  = 1 # Din 0 in 1
    w2  = 1
    b   = 0
    rezultat = functie_de_activare(w1 * x1 + w2 * x2 + b)
    print(x1, "and", x2, "=", rezultat)

AND_neuron(1, 1)
AND_neuron(0, 1)
AND_neuron(1, 0)
AND_neuron(0, 0)
# Out:
# 1 and 1 = 2
# 0 and 1 = 1
# 1 and 0 = 1
# 0 and 0 = 0

# %%
def functie_de_activare(x):
    return x

def AND_neuron(x1, x2):
    w1  = 1 # Din 0 in 1
    w2  = 1
    b   = -1
    rezultat = functie_de_activare(w1 * x1 + w2 * x2 + b)
    print(x1, "and", x2, "=", rezultat)

AND_neuron(1, 1)
AND_neuron(0, 1)
AND_neuron(1, 0)
AND_neuron(0, 0)
# Out:
# 1 and 1 = 1
# 0 and 1 = 0
# 1 and 0 = 0
# 0 and 0 = -1

# %%
def functie_de_activare(x):
    return 1 if x > 0 else 0

def AND_neuron(x1, x2):
    w1  = 1 # Din 0 in 1
    w2  = 1
    b   = -1
    rezultat = functie_de_activare(w1 * x1 + w2 * x2 + b)
    print(x1, "and", x2, "=", rezultat)

AND_neuron(1, 1)
AND_neuron(0, 1)
AND_neuron(1, 0)
AND_neuron(0, 0)
# Out:
# 1 and 1 = 1
# 0 and 1 = 0
# 1 and 0 = 0
# 0 and 0 = 0

# %%
def functie_de_activare(x):
    return 1 if x > 0 else 0

def AND_neuron(x1, x2):
    w1  = 1 # Din 0 in 1
    w2  = 1
    b   = -1.5
    rezultat = functie_de_activare(w1 * x1 + w2 * x2 + b)
    print(x1, "and", x2, "=", rezultat)

AND_neuron(1, 1)
AND_neuron(0, 1)
AND_neuron(1, 0)
AND_neuron(0, 0)
# Out:
# 1 and 1 = 1
# 0 and 1 = 0
# 1 and 0 = 0
# 0 and 0 = 0

# %%
AND_neuron(10, 12)
AND_neuron(0, 1)
AND_neuron(1, 0)
AND_neuron(0, 0)
# Out:
# 10 and 12 = 1
# 0 and 1 = 0
# 1 and 0 = 0
# 0 and 0 = 0

# %% [markdown]
# # Exercitiu -> OR ca neuron

# %%
def OR_clasic(x1, x2):
    print(x1, "or", x2, "=", x1 or x2)

# %%
OR_clasic(True, True)
OR_clasic(False, True)
OR_clasic(True, False)
OR_clasic(False, False)
# Out:
# True or True = True
# False or True = True
# True or False = True
# False or False = False

# %%
OR_clasic(1, 1)
OR_clasic(0, 1)
OR_clasic(1, 0)
OR_clasic(0, 0)
# Out:
# 1 or 1 = 1
# 0 or 1 = 1
# 1 or 0 = 1
# 0 or 0 = 0

# %%
def functie_de_activare(x):
    return 1 if x > 0 else 0

def OR_neuron(x1, x2):
    w1  = 1 # Din 0 in 1
    w2  = 1
    b   = 0
    rezultat = functie_de_activare(w1 * x1 + w2 * x2 + b)
    print(x1, "or", x2, "=", rezultat)

OR_neuron(1, 1)
OR_neuron(0, 1)
OR_neuron(1, 0)
OR_neuron(0, 0)
# Out:
# 1 or 1 = 1
# 0 or 1 = 1
# 1 or 0 = 1
# 0 or 0 = 0

# %%
OR_neuron(1, 1)
OR_neuron(0, 1)
OR_neuron(1, 0)
OR_neuron(0, 0)
# Out:
# 1 or 1 = 1
# 0 or 1 = 1
# 1 or 0 = 1
# 0 or 0 = 0

# %%
10 and 0
# Out:
# 0

# %%
10 or 20
# Out:
# 10

# %%
def functie_de_activare(x):
    return 1 if x > 0 else 0

def OR_neuron(x1, x2):
    w1  = 1 # Din 0 in 1
    w2  = 1
    b   = 0
    rezultat = functie_de_activare(w1 * x1 + w2 * x2 + b)
    print(x1, "or", x2, "=", rezultat)

OR_neuron(1, 1)
OR_neuron(0, 1)
OR_neuron(1, 0)
OR_neuron(0, 0)
# Out:
# 1 or 1 = 1
# 0 or 1 = 1
# 1 or 0 = 1
# 0 or 0 = 0

# %%
from sklearn.neural_network import MLPClassifier
